# %%
import pickle
import os
import random
import numpy as np
from pathlib import Path
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
# Out:
# 2022-04-17 21:23:54.728898: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# # data pre-processing

# %%
def wh_ETL(dir_path, idx, mode='train', feature_range=(0, 1), pickle_save_dir='models_save/test1/pickles'):
    # load from folder
    whs = list(Path(dir_path).glob('*.npy'))
    whs = np.stack([np.load(path) for path in whs])
    print(whs.shape)
    nb_test_samples = int(0.2 * whs.shape[0])
    whs = whs[idx]
    if mode is 'train':
        whs = whs[2*nb_test_samples:]
    elif mode is 'val':
        whs = whs[0:nb_test_samples]
    else:
        whs = whs[nb_test_samples:2*nb_test_samples]    
    
    # move sample axis to the last, reshape, and remove the first layer
    whs = np.moveaxis(whs, 1, 3).reshape(-1, 34)[:, 1:]
    
    # Min Max normalization
    scaler = MinMaxScaler(feature_range=feature_range)
    scaled_whs = scaler.fit_transform(whs)
    
    # PCA
    pca = PCA(n_components=0.96, svd_solver='full')
    out = pca.fit_transform(scaled_whs)
    
    # save scaler and pca as pickles
    if mode is 'train':
        Path(pickle_save_dir).mkdir(parents=True, exist_ok=True)
        pickle.dump(scaler, open(f'{pickle_save_dir}/scaler.pkl', 'wb'))
        pickle.dump(pca, open(f'{pickle_save_dir}/pca.pkl', 'wb'))
    return out.astype(np.float32), pca


def load_X(dir_path, feature_range=(0, 1)):
    Vars = []
    names = [p.name for p in Path(X_path).glob('*/')]
    for name in names:
        path = Path(X_path).joinpath(name)
        data = np.stack([np.load(p) for p in path.glob('*.npy')])
        if name == 'cape':
            data = data[:, np.newaxis, ..., np.newaxis]
            data = np.concatenate([data]*34, axis=1)
        else:
            data = data[..., np.newaxis]
        Vars.append(data)
    X = np.concatenate(Vars, axis=-1)[:, 1:, ...]
    X = np.moveaxis(X, 1, -2)
    shape = X.shape
        
    # stdandardlization
    scaler = MinMaxScaler(feature_range=feature_range)
    X = X.reshape(-1, 9)
    X = scaler.fit_transform(X)
    X = X.reshape(shape)
    
    return X.astype(np.float32), scaler


def pad_boundary(arr, kernel_size):
    '''
    arr : input array
    kernel_size : training sample size
    '''

    pad_size = int((kernel_size - 1) / 2)

    if len(arr.shape) == 5:
        pad_arr = np.pad(arr, pad_size, 'wrap')
        pad_arr = pad_arr[pad_size:-pad_size, ..., pad_size:-pad_size, pad_size:-pad_size]
    else:
        raise ValueError('len(arr.shape) should be 5')
    return pad_arr


def X_ETL(path, idx, mode='train', feature_range=(0,1), pickle_save_dir='models_save/test1/pickles'):
    # load_X and select train/val/test set due to lack of memory
    X, scaler = load_X(path, feature_range)
    nb_test_samples = int(0.2 * X.shape[0])
    
    # shuffle
    X = X[idx]
    
    # split
    if mode is 'train':
        X = X[2*nb_test_samples:]
    elif mode is 'val':
        X = X[0:nb_test_samples]
    else:
        X = X[nb_test_samples:2*nb_test_samples]
    
    print(X.shape)
    # CNN input style
    X = pad_boundary(X, 7)
    print(X.shape)
    X = np.lib.stride_tricks.sliding_window_view(X, (7, 7), axis=(1, 2))
    print(X.shape)
    X = np.moveaxis(X, 4, -1)
    print(X.shape)
    
    # save scaler and pca as pickles
    if mode is 'train':
        Path(pickle_save_dir).mkdir(parents=True, exist_ok=True)
        pickle.dump(scaler, open(f'{pickle_save_dir}/scaler_X.pkl', 'wb'))
    return X.reshape(-1, 33, 7, 7, 9)

# %%
# split data
seed = 777
idx = np.arange(1314)
random.seed(seed)
random.shuffle(idx)
nb_test_samples = int(0.2 * idx.shape[0])

# %%
# y preprocess
wh_path = 'data/target/wh/'
pickle_save_dir='model_save/test1/pickles'
mode = 'test'
y, pca = wh_ETL(wh_path, idx, mode=mode, pickle_save_dir=pickle_save_dir)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3390085/65000590.py in <module>
#       3 pickle_save_dir='model_save/test1/pickles'
#       4 mode = 'test'
# ----> 5 y, pca = wh_ETL(wh_path, idx, mode=mode, pickle_save_dir=pickle_save_dir)
#
# /tmp/ipykernel_3390085/3080897917.py in wh_ETL(dir_path, idx, mode, feature_range, pickle_save_dir)
#       2     # load from folder
#       3     whs = list(Path(dir_path).glob('*.npy'))
# ----> 4     whs = np.stack([np.load(path) for path in whs])
#       5     print(whs.shape)
#       6     nb_test_samples = int(0.2 * whs.shape[0])
#
# /tmp/ipykernel_3390085/3080897917.py in <listcomp>(.0)
#       2     # load from folder
#       3     whs = list(Path(dir_path).glob('*.npy'))
# ----> 4     whs = np.stack([np.load(path) for path in whs])
#       5     print(whs.shape)
#       6     nb_test_samples = int(0.2 * whs.shape[0])
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     435         elif magic == format.MAGIC_PREFIX:
#     436             # .npy file
# --> 437             if mmap_mode:
#     438                 return format.open_memmap(file, mode=mmap_mode)
#     439             else:
#
# KeyboardInterrupt:

# %%
y.shape, y.dtype
# Out:
# ((268288, 5), dtype('float32'))

# %%
X.shape
# Out:
# (268288, 33, 7, 7, 9)

# %%
X_shape
# Out:
# (44402688, 9)

# %%
X_shape = X.shape

# %%
pca = pickle.load(open('models_save/test1/pickles/pca.pkl', 'rb'),)

# %%
pca.inverse_transform(y).shape
# Out:
# (808960, 33)

# %%
# X preprocess
mode = 'test'
X_path = 'data/vars/'
X = X_ETL(X_path, idx, mode=mode)

# %%
X.shape
# Out:
# (268288, 33, 7, 7, 9)

# %%
names = [p.name for p in Path(X_path).glob('*/')]
names
# Out:
# ['cape', 'mfd', 'mse', 'q', 't', 'u', 'v', 'w', 'z']

# %%
np.save('X_test_ori.npy', X)

# %%
X.shape, y.shape
# Out:
# ((268288, 33, 7, 7, 9), (268288, 5))

# %%
y.dtype
# Out:
# dtype('float64')

# %% [markdown]
# # save as tf record dataset

# %%
def _bytes_feature(value):
    """Returns a bytes_list from a string / byte."""
    if isinstance(value, type(tf.constant(0))): # if value ist tensor
        value = value.numpy() # get value of tensor
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

def _float_feature(value):
    """Returns a floast_list from a float / double."""
    return tf.train.Feature(float_list=tf.train.FloatList(value=[value]))

def _int64_feature(value):
    """Returns an int64_list from a bool / enum / int / uint."""
    return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))

def serialize_array(array):
    array = tf.io.serialize_tensor(array)
    return array

def parse_single_data(feature, label):
    #define the dictionary -- the structure -- of our single example
    data = {
        'feature' : _bytes_feature(tf.io.serialize_tensor(feature).numpy()),
        'label' : _bytes_feature(tf.io.serialize_tensor(label).numpy())
    }

    out = tf.train.Example(features=tf.train.Features(feature=data))
    return out

def write_data_to_tfr_short(datas, labels, filename:str="data"):
    filename= filename+".tfrecords"
    writer = tf.io.TFRecordWriter(filename) #create a writer that'll store our data to disk
    count = 0

    for index in range(len(datas)):

        #get the data we want to write
        current_data = datas[index]
        current_label = labels[index]

        out = parse_single_data(feature=current_data, label=current_label)
        writer.write(out.SerializeToString())
        count += 1

    writer.close()
    print(f"Wrote {count} elements to TFRecord")
    return count

def _parse_data_function(example_proto):
    data_feature_description = {
        'feature' : tf.io.FixedLenFeature([], tf.string),
        'label' : tf.io.FixedLenFeature([], tf.string)
    }

    # Parse the input tf.train.Example proto using the dictionary above.
    features = tf.io.parse_single_example(example_proto, data_feature_description)
    features['feature'] = tf.io.parse_tensor(features['feature'], 'float')
    features['label'] = tf.io.parse_tensor(features['label'], 'float')
    return features

# %%
# write data to TFRecord
# write_data_to_tfr_short(X, y, filename='test_dataset_0417')

def _parse_data_function(example_proto):
    data_feature_description = {
        'feature' : tf.io.FixedLenFeature([], tf.string),
        'label' : tf.io.FixedLenFeature([], tf.string)
    }

    # Parse the input tf.train.Example proto using the dictionary above.
    features = tf.io.parse_single_example(example_proto, data_feature_description)
    data = tf.io.parse_tensor(features['feature'], "float") 
    label = tf.io.parse_tensor(features['label'], "float")
    data.set_shape([33,7,7,9])
    label.set_shape([5,])
    return data, label

# read TFRecord
raw_dataset = tf.data.TFRecordDataset('test_dataset_0417.tfrecords')
parsed_dataset = raw_dataset.map(_parse_data_function)

# %%
def _parse_data_function(example_proto):
    data_feature_description = {
        'feature' : tf.io.FixedLenFeature([], tf.string),
        'label' : tf.io.FixedLenFeature([], tf.string)
    }

    # Parse the input tf.train.Example proto using the dictionary above.
    features = tf.io.parse_single_example(example_proto, data_feature_description)
    data = tf.io.parse_tensor(features['feature'], "float") 
    label = tf.io.parse_tensor(features['label'], "float")
    data.set_shape([33,7,7,9])
    label.set_shape([5,])
    return data, label


def get_dataset(dataset, BATCH_SIZE):
    dataset = dataset.shuffle(2048)
    dataset = dataset.prefetch(buffer_size=AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE)
    return dataset

train_dataset = raw_dataset.map(_parse_data_function)
train_dataset = get_dataset(train_dataset, BATCH_SIZE)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
model = CNN3D(9)

# Train model on dataset
model.fit(train_dataset,
          epochs=1000,
          batch_size=64)
# Out:
# Epoch 1/1000
# 2022-04-17 23:45:24.025415: W tensorflow/core/common_runtime/bfc_allocator.cc:456] Allocator (GPU_0_bfc) ran out of memory trying to allocate 56.85MiB (rounded to 59609088)requested by op SameWorkerRecvDone
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-04-17 23:45:24.025590: I tensorflow/core/common_runtime/bfc_allocator.cc:991] BFCAllocator dump for GPU_0_bfc
# 2022-04-17 23:45:24.025633: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (256): 	Total Chunks: 294, Chunks in use: 293. 73.5KiB allocated for chunks. 73.2KiB in use in bin. 19.8KiB client-requested in use in bin.
# 2022-04-17 23:45:24.025664: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (512): 	Total Chunks: 44, Chunks in use: 44. 22.2KiB allocated for chunks. 22.2KiB in use in bin. 22.0KiB client-requested in use in bin.
# 2022-04-17 23:45:24.025691: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2022-04-17 23:45:24.025716: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-04-17 23:45:24.025740: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-04-17 23:45:24.025770: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (8192): 	Total Chunks: 22, Chunks in use: 22. 212.0KiB allocated for chunks. 212.0KiB in use in bin. 198.0KiB client-requested in use in bin.
# 2022-04-17 23:45:24.025797: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (16384): 	Total Chunks: 23, Chunks in use: 23. 492.0KiB allocated for chunks. 492.0KiB in use in bin. 460.0KiB client-requested in use in bin.
# 2022-04-17 23:45:24.025820: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-04-17 23:45:24.025846: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (65536): 	Total Chunks: 44, Chunks in use: 44. 2.80MiB allocated for chunks. 2.80MiB in use in bin. 2.75MiB client-requested in use in bin.
# 2022-04-17 23:45:24.025877: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (131072): 	Total Chunks: 22, Chunks in use: 22. 2.78MiB allocated for chunks. 2.78MiB in use in bin. 2.75MiB client-requested in use in bin.
# 2022-04-17 23:45:24.025921: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (262144): 	Total Chunks: 44, Chunks in use: 44. 11.18MiB allocated for chunks. 11.18MiB in use in bin. 11.00MiB client-requested in use in bin.
# 2022-04-17 23:45:24.025958: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-04-17 23:45:24.025992: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-04-17 23:45:24.026032: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-04-17 23:45:24.026074: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-04-17 23:45:24.026108: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-04-17 23:45:24.026141: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-04-17 23:45:24.026179: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (33554432): 	Total Chunks: 1, Chunks in use: 0. 42.20MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-04-17 23:45:24.026235: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-04-17 23:45:24.026277: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-04-17 23:45:24.026312: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-04-17 23:45:24.026353: I tensorflow/core/common_runtime/bfc_allocator.cc:1014] Bin for 56.85MiB was 32.00MiB, Chunk State:
# 2022-04-17 23:45:24.026415: I tensorflow/core/common_runtime/bfc_allocator.cc:1020]   Size: 42.20MiB | Requested Size: 0B | in_use: 0 | bin_num: 17, prev:   Size: 256B | Requested Size: 4B | in_use: 1 | bin_num: -1, for: Cast, stepid: 17536421437266244153, last_action: 1422, for: UNUSED, stepid: 0, last_action: 0
# 2022-04-17 23:45:24.026448: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] Next region of size 62652416
# 2022-04-17 23:45:24.026501: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26000000 of size 1280 by op ScratchBuffer action_count 1 step 0 next 1
# 2022-04-17 23:45:24.026542: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26000500 of size 256 by op AssignVariableOp action_count 2 step 0 next 2
# 2022-04-17 23:45:24.026577: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26000600 of size 256 by op Fill action_count 3 step 0 next 3
# 2022-04-17 23:45:24.026616: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26000700 of size 256 by op Fill action_count 167 step 0 next 4
# 2022-04-17 23:45:24.026649: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26000800 of size 256 by op Fill action_count 5 step 0 next 5
# 2022-04-17 23:45:24.026687: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26000900 of size 512 by op Fill action_count 194 step 0 next 29
# 2022-04-17 23:45:24.026727: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26000b00 of size 256 by op Fill action_count 210 step 0 next 31
# 2022-04-17 23:45:24.026763: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26000c00 of size 256 by op Fill action_count 226 step 0 next 12
# 2022-04-17 23:45:24.026796: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26000d00 of size 256 by op Sub action_count 20 step 0 next 16
# 2022-04-17 23:45:24.026837: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26000e00 of size 256 by op Sub action_count 21 step 0 next 17
# 2022-04-17 23:45:24.026873: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26000f00 of size 256 by op Equal action_count 161 step 0 next 15
# 2022-04-17 23:45:24.026912: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26001000 of size 256 by op Sub action_count 30 step 0 next 21
# 2022-04-17 23:45:24.026944: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26001100 of size 256 by op Sub action_count 31 step 0 next 22
# 2022-04-17 23:45:24.026980: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26001200 of size 256 by op Fill action_count 169 step 0 next 35
# 2022-04-17 23:45:24.027015: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26001300 of size 256 by op Fill action_count 170 step 0 next 20
# 2022-04-17 23:45:24.027048: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26001400 of size 256 by op Sub action_count 40 step 0 next 25
# 2022-04-17 23:45:24.027085: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26001500 of size 256 by op Sub action_count 41 step 0 next 26
# 2022-04-17 23:45:24.027120: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26001600 of size 512 by op Fill action_count 218 step 0 next 8
# 2022-04-17 23:45:24.027150: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26001800 of size 256 by op Fill action_count 227 step 0 next 7
# 2022-04-17 23:45:24.027181: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26001900 of size 256 by op Fill action_count 228 step 0 next 34
# 2022-04-17 23:45:24.027230: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26001a00 of size 256 by op Sub action_count 66 step 0 next 36
# 2022-04-17 23:45:24.027262: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26001b00 of size 256 by op Sub action_count 67 step 0 next 37
# 2022-04-17 23:45:24.027299: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26001c00 of size 256 by op Fill action_count 178 step 0 next 39
# 2022-04-17 23:45:24.027336: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26001d00 of size 256 by op Fill action_count 186 step 0 next 30
# 2022-04-17 23:45:24.027366: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26001e00 of size 256 by op Fill action_count 202 step 0 next 40
# 2022-04-17 23:45:24.027401: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26001f00 of size 256 by op AssignVariableOp action_count 77 step 0 next 41
# 2022-04-17 23:45:24.027434: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26002000 of size 256 by op Fill action_count 78 step 0 next 42
# 2022-04-17 23:45:24.027464: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26002100 of size 256 by op Fill action_count 79 step 0 next 43
# 2022-04-17 23:45:24.027496: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26002200 of size 256 by op Fill action_count 80 step 0 next 44
# 2022-04-17 23:45:24.027527: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26002300 of size 256 by op Fill action_count 81 step 0 next 45
# 2022-04-17 23:45:24.027559: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26002400 of size 256 by op Fill action_count 89 step 0 next 48
# 2022-04-17 23:45:24.027592: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26002500 of size 256 by op Fill action_count 97 step 0 next 49
# 2022-04-17 23:45:24.027627: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26002600 of size 512 by op Fill action_count 105 step 0 next 53
# 2022-04-17 23:45:24.027660: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26002800 of size 256 by op Fill action_count 113 step 0 next 55
# 2022-04-17 23:45:24.027690: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26002900 of size 256 by op Fill action_count 121 step 0 next 56
# 2022-04-17 23:45:24.027721: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26002a00 of size 512 by op Fill action_count 129 step 0 next 60
# 2022-04-17 23:45:24.027751: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26002c00 of size 256 by op Fill action_count 137 step 0 next 63
# 2022-04-17 23:45:24.027778: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26002d00 of size 256 by op Fill action_count 138 step 0 next 64
# 2022-04-17 23:45:24.027797: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26002e00 of size 256 by op Fill action_count 139 step 0 next 65
# 2022-04-17 23:45:24.027816: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26002f00 of size 256 by op Fill action_count 168 step 0 next 9
# 2022-04-17 23:45:24.027835: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26003000 of size 256 by op Sub action_count 10 step 0 next 10
# 2022-04-17 23:45:24.027854: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26003100 of size 256 by op Sub action_count 11 step 0 next 11
# 2022-04-17 23:45:24.027885: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26003200 of size 131072 by op Add action_count 267 step 0 next 74
# 2022-04-17 23:45:24.027918: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26023200 of size 65536 by op Add action_count 387 step 0 next 113
# 2022-04-17 23:45:24.027953: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26033200 of size 93440 by op Add action_count 411 step 0 next 47
# 2022-04-17 23:45:24.027986: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26049f00 of size 9216 by op Add action_count 86 step 0 next 46
# 2022-04-17 23:45:24.028019: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2604c300 of size 9216 by op Add action_count 175 step 0 next 28
# 2022-04-17 23:45:24.028051: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2604e700 of size 65536 by op Add action_count 207 step 0 next 24
# 2022-04-17 23:45:24.028082: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605e700 of size 256 by op Fill action_count 235 step 0 next 6
# 2022-04-17 23:45:24.028115: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605e800 of size 256 by op Fill action_count 236 step 0 next 38
# 2022-04-17 23:45:24.028146: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605e900 of size 256 by op Fill action_count 237 step 0 next 66
# 2022-04-17 23:45:24.028177: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605ea00 of size 256 by op Fill action_count 238 step 0 next 67
# 2022-04-17 23:45:24.028214: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605eb00 of size 256 by op Fill action_count 450 step 0 next 129
# 2022-04-17 23:45:24.028234: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605ec00 of size 256 by op Fill action_count 458 step 0 next 133
# 2022-04-17 23:45:24.028253: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605ed00 of size 512 by op Fill action_count 466 step 0 next 136
# 2022-04-17 23:45:24.028275: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605ef00 of size 256 by op Fill action_count 474 step 0 next 137
# 2022-04-17 23:45:24.028307: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605f000 of size 256 by op Fill action_count 482 step 0 next 140
# 2022-04-17 23:45:24.028336: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605f100 of size 512 by op Fill action_count 490 step 0 next 143
# 2022-04-17 23:45:24.028367: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605f300 of size 256 by op Fill action_count 498 step 0 next 145
# 2022-04-17 23:45:24.028402: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605f400 of size 256 by op Fill action_count 499 step 0 next 146
# 2022-04-17 23:45:24.028433: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605f500 of size 256 by op Fill action_count 500 step 0 next 147
# 2022-04-17 23:45:24.028464: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605f600 of size 256 by op Fill action_count 507 step 0 next 148
# 2022-04-17 23:45:24.028506: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605f700 of size 256 by op AssignVariableOp action_count 508 step 0 next 149
# 2022-04-17 23:45:24.028539: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605f800 of size 256 by op AssignVariableOp action_count 509 step 0 next 150
# 2022-04-17 23:45:24.028565: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605f900 of size 256 by op AssignVariableOp action_count 510 step 0 next 151
# 2022-04-17 23:45:24.028584: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605fa00 of size 256 by op AssignVariableOp action_count 511 step 0 next 152
# 2022-04-17 23:45:24.028603: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605fb00 of size 256 by op Fill action_count 642 step 0 next 153
# 2022-04-17 23:45:24.028630: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605fc00 of size 256 by op Fill action_count 513 step 0 next 154
# 2022-04-17 23:45:24.028661: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605fd00 of size 256 by op Fill action_count 514 step 0 next 155
# 2022-04-17 23:45:24.028698: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605fe00 of size 256 by op Fill action_count 515 step 0 next 156
# 2022-04-17 23:45:24.028730: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2605ff00 of size 256 by op Fill action_count 517 step 0 next 157
# 2022-04-17 23:45:24.028761: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26060000 of size 256 by op Fill action_count 519 step 0 next 158
# 2022-04-17 23:45:24.028793: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26060100 of size 512 by op Fill action_count 521 step 0 next 159
# 2022-04-17 23:45:24.028824: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26060300 of size 256 by op Fill action_count 523 step 0 next 160
# 2022-04-17 23:45:24.028856: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26060400 of size 256 by op Fill action_count 525 step 0 next 161
# 2022-04-17 23:45:24.028877: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26060500 of size 512 by op Fill action_count 527 step 0 next 162
# 2022-04-17 23:45:24.028896: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26060700 of size 256 by op Fill action_count 529 step 0 next 163
# 2022-04-17 23:45:24.028917: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26060800 of size 256 by op Fill action_count 530 step 0 next 164
# 2022-04-17 23:45:24.028948: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26060900 of size 256 by op Fill action_count 531 step 0 next 165
# 2022-04-17 23:45:24.028978: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26060a00 of size 256 by op Fill action_count 533 step 0 next 167
# 2022-04-17 23:45:24.029012: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26060b00 of size 256 by op Fill action_count 535 step 0 next 168
# 2022-04-17 23:45:24.029044: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26060c00 of size 512 by op Fill action_count 537 step 0 next 170
# 2022-04-17 23:45:24.029075: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26060e00 of size 256 by op Fill action_count 539 step 0 next 172
# 2022-04-17 23:45:24.029108: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26060f00 of size 256 by op Fill action_count 541 step 0 next 130
# 2022-04-17 23:45:24.029144: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26061000 of size 9984 by op Add action_count 447 step 0 next 13
# 2022-04-17 23:45:24.029173: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26063700 of size 20480 by op Add action_count 223 step 0 next 14
# 2022-04-17 23:45:24.029206: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26068700 of size 9216 by op Add action_count 311 step 0 next 90
# 2022-04-17 23:45:24.029227: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2606ab00 of size 31744 by op Fill action_count 544 step 0 next 83
# 2022-04-17 23:45:24.029256: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26072700 of size 21504 by op Add action_count 291 step 0 next 27
# 2022-04-17 23:45:24.029287: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26077b00 of size 65536 by op Add action_count 94 step 0 next 50
# 2022-04-17 23:45:24.029321: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26087b00 of size 131072 by op Add action_count 403 step 0 next 118
# 2022-04-17 23:45:24.029355: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d260a7b00 of size 327680 by op Fill action_count 526 step 0 next 23
# 2022-04-17 23:45:24.029386: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d260f7b00 of size 131072 by op Add action_count 110 step 0 next 54
# 2022-04-17 23:45:24.029419: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26117b00 of size 65536 by op Add action_count 118 step 0 next 57
# 2022-04-17 23:45:24.029451: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26127b00 of size 9216 by op Add action_count 243 step 0 next 70
# 2022-04-17 23:45:24.029481: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26129f00 of size 256 by op Fill action_count 246 step 0 next 68
# 2022-04-17 23:45:24.029502: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612a000 of size 256 by op Fill action_count 254 step 0 next 69
# 2022-04-17 23:45:24.029521: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612a100 of size 512 by op Fill action_count 262 step 0 next 73
# 2022-04-17 23:45:24.029548: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612a300 of size 256 by op Fill action_count 270 step 0 next 75
# 2022-04-17 23:45:24.029578: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612a400 of size 256 by op Fill action_count 278 step 0 next 76
# 2022-04-17 23:45:24.029611: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612a500 of size 512 by op Fill action_count 286 step 0 next 80
# 2022-04-17 23:45:24.029643: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612a700 of size 256 by op Fill action_count 294 step 0 next 81
# 2022-04-17 23:45:24.029675: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612a800 of size 256 by op Fill action_count 295 step 0 next 82
# 2022-04-17 23:45:24.029707: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612a900 of size 256 by op Fill action_count 296 step 0 next 84
# 2022-04-17 23:45:24.029738: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612aa00 of size 256 by op Fill action_count 303 step 0 next 85
# 2022-04-17 23:45:24.029769: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612ab00 of size 256 by op Fill action_count 304 step 0 next 86
# 2022-04-17 23:45:24.029789: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612ac00 of size 256 by op Fill action_count 305 step 0 next 87
# 2022-04-17 23:45:24.029809: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612ad00 of size 256 by op Fill action_count 306 step 0 next 88
# 2022-04-17 23:45:24.029832: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612ae00 of size 256 by op Fill action_count 314 step 0 next 89
# 2022-04-17 23:45:24.029862: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612af00 of size 256 by op Fill action_count 322 step 0 next 91
# 2022-04-17 23:45:24.029894: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612b000 of size 512 by op Fill action_count 330 step 0 next 94
# 2022-04-17 23:45:24.029928: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612b200 of size 256 by op Fill action_count 338 step 0 next 95
# 2022-04-17 23:45:24.029959: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612b300 of size 256 by op Fill action_count 346 step 0 next 98
# 2022-04-17 23:45:24.029990: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612b400 of size 512 by op Fill action_count 354 step 0 next 101
# 2022-04-17 23:45:24.030023: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612b600 of size 256 by op Fill action_count 362 step 0 next 104
# 2022-04-17 23:45:24.030054: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612b700 of size 256 by op Fill action_count 363 step 0 next 105
# 2022-04-17 23:45:24.030079: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612b800 of size 256 by op Fill action_count 364 step 0 next 106
# 2022-04-17 23:45:24.030098: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612b900 of size 256 by op Fill action_count 371 step 0 next 107
# 2022-04-17 23:45:24.030117: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612ba00 of size 256 by op Fill action_count 372 step 0 next 108
# 2022-04-17 23:45:24.030149: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612bb00 of size 256 by op Fill action_count 373 step 0 next 109
# 2022-04-17 23:45:24.030180: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612bc00 of size 256 by op Fill action_count 374 step 0 next 110
# 2022-04-17 23:45:24.030231: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612bd00 of size 256 by op Fill action_count 382 step 0 next 111
# 2022-04-17 23:45:24.030262: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612be00 of size 256 by op Fill action_count 390 step 0 next 114
# 2022-04-17 23:45:24.030293: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612bf00 of size 512 by op Fill action_count 398 step 0 next 116
# 2022-04-17 23:45:24.030326: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612c100 of size 256 by op Fill action_count 406 step 0 next 117
# 2022-04-17 23:45:24.030358: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612c200 of size 256 by op Fill action_count 414 step 0 next 119
# 2022-04-17 23:45:24.030381: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612c300 of size 512 by op Fill action_count 422 step 0 next 121
# 2022-04-17 23:45:24.030401: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612c500 of size 256 by op Fill action_count 430 step 0 next 123
# 2022-04-17 23:45:24.030419: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612c600 of size 256 by op Fill action_count 431 step 0 next 124
# 2022-04-17 23:45:24.030444: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612c700 of size 256 by op Fill action_count 432 step 0 next 125
# 2022-04-17 23:45:24.030476: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612c800 of size 256 by op Fill action_count 439 step 0 next 126
# 2022-04-17 23:45:24.030507: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612c900 of size 256 by op Fill action_count 440 step 0 next 127
# 2022-04-17 23:45:24.030542: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612ca00 of size 256 by op Fill action_count 441 step 0 next 62
# 2022-04-17 23:45:24.030574: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2612cb00 of size 20480 by op Add action_count 134 step 0 next 61
# 2022-04-17 23:45:24.030606: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26131b00 of size 262144 by op Add action_count 191 step 0 next 32
# 2022-04-17 23:45:24.030640: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26171b00 of size 131072 by op Add action_count 199 step 0 next 18
# 2022-04-17 23:45:24.030671: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26191b00 of size 65536 by op Add action_count 275 step 0 next 77
# 2022-04-17 23:45:24.030696: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d261a1b00 of size 90112 by op Fill action_count 534 step 0 next 52
# 2022-04-17 23:45:24.030715: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d261b7b00 of size 262144 by op Add action_count 102 step 0 next 51
# 2022-04-17 23:45:24.030743: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d261f7b00 of size 65536 by op Add action_count 183 step 0 next 33
# 2022-04-17 23:45:24.030774: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26207b00 of size 65536 by op Add action_count 251 step 0 next 71
# 2022-04-17 23:45:24.030808: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26217b00 of size 9216 by op Add action_count 379 step 0 next 112
# 2022-04-17 23:45:24.030839: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26219f00 of size 256 by op Fill action_count 442 step 0 next 128
# 2022-04-17 23:45:24.030871: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2621a000 of size 11008 by op Fill action_count 516 step 0 next 103
# 2022-04-17 23:45:24.030904: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2621cb00 of size 20480 by op Add action_count 359 step 0 next 102
# 2022-04-17 23:45:24.030937: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26221b00 of size 24576 by op Fill action_count 528 step 0 next 92
# 2022-04-17 23:45:24.030963: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26227b00 of size 65536 by op Add action_count 319 step 0 next 59
# 2022-04-17 23:45:24.030982: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26237b00 of size 262144 by op Add action_count 126 step 0 next 58
# 2022-04-17 23:45:24.031001: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26277b00 of size 262144 by op Add action_count 215 step 0 next 19
# 2022-04-17 23:45:24.031030: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d262b7b00 of size 262144 by op Add action_count 259 step 0 next 72
# 2022-04-17 23:45:24.031061: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d262f7b00 of size 65536 by op Add action_count 343 step 0 next 97
# 2022-04-17 23:45:24.031095: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26307b00 of size 20480 by op Add action_count 427 step 0 next 122
# 2022-04-17 23:45:24.031126: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2630cb00 of size 20480 by op Add action_count 495 step 0 next 144
# 2022-04-17 23:45:24.031157: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26311b00 of size 9216 by op Fill action_count 532 step 0 next 166
# 2022-04-17 23:45:24.031190: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26313f00 of size 512 by op Fill action_count 543 step 0 next 175
# 2022-04-17 23:45:24.031238: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26314100 of size 256 by op Fill action_count 545 step 0 next 176
# 2022-04-17 23:45:24.031264: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26314200 of size 256 by op Nadam/Cast_5/x action_count 546 step 0 next 177
# 2022-04-17 23:45:24.031284: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26314300 of size 256 by op Nadam/add_1/y action_count 547 step 0 next 178
# 2022-04-17 23:45:24.031303: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26314400 of size 256 by op Nadam/mul/x action_count 548 step 0 next 179
# 2022-04-17 23:45:24.031329: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26314500 of size 256 by op Nadam/mul_1/x action_count 549 step 0 next 180
# 2022-04-17 23:45:24.031361: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26314600 of size 256 by op Nadam/Const action_count 550 step 0 next 181
# 2022-04-17 23:45:24.031392: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26314700 of size 256 by op Nadam/sub_4/x action_count 551 step 0 next 182
# 2022-04-17 23:45:24.031426: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26314800 of size 256 by op Nadam/add/y action_count 552 step 0 next 183
# 2022-04-17 23:45:24.031458: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26314900 of size 256 by op sequential_6/batch_normalization_6/batchnorm/add/y action_count 553 step 0 next 184
# 2022-04-17 23:45:24.031491: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26314a00 of size 256 by op sequential_6/batch_normalization_6/AssignMovingAvg/decay action_count 554 step 0 next 185
# 2022-04-17 23:45:24.031524: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26314b00 of size 256 by op gradient_tape/mean_squared_error/scalar action_count 555 step 0 next 186
# 2022-04-17 23:45:24.031556: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26314c00 of size 256 by op Const action_count 556 step 0 next 187
# 2022-04-17 23:45:24.031606: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26314d00 of size 256 by op Nadam/Nadam/Const action_count 557 step 0 next 188
# 2022-04-17 23:45:24.031625: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26314e00 of size 256 by op Fill action_count 643 step 0 next 192
# 2022-04-17 23:45:24.031645: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26314f00 of size 256 by op Fill action_count 644 step 0 next 224
# 2022-04-17 23:45:24.031673: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26315000 of size 256 by op Fill action_count 645 step 0 next 225
# 2022-04-17 23:45:24.031705: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26315100 of size 10752 by op Fill action_count 714 step 0 next 96
# 2022-04-17 23:45:24.031738: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26317b00 of size 131072 by op Add action_count 335 step 0 next 79
# 2022-04-17 23:45:24.031772: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26337b00 of size 262144 by op Add action_count 283 step 0 next 78
# 2022-04-17 23:45:24.031803: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26377b00 of size 262144 by op Add action_count 327 step 0 next 93
# 2022-04-17 23:45:24.031836: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d263b7b00 of size 65536 by op Fill action_count 518 step 0 next 132
# 2022-04-17 23:45:24.031866: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d263c7b00 of size 65536 by op Add action_count 455 step 0 next 131
# 2022-04-17 23:45:24.031895: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d263d7b00 of size 65536 by op Add action_count 479 step 0 next 139
# 2022-04-17 23:45:24.031916: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d263e7b00 of size 65536 by op Fill action_count 524 step 0 next 100
# 2022-04-17 23:45:24.031935: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d263f7b00 of size 262144 by op Add action_count 351 step 0 next 99
# 2022-04-17 23:45:24.031962: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26437b00 of size 262144 by op Add action_count 395 step 0 next 115
# 2022-04-17 23:45:24.031992: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26477b00 of size 262144 by op Add action_count 419 step 0 next 120
# 2022-04-17 23:45:24.032026: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d264b7b00 of size 131072 by op Fill action_count 522 step 0 next 138
# 2022-04-17 23:45:24.032059: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d264d7b00 of size 131072 by op Add action_count 471 step 0 next 135
# 2022-04-17 23:45:24.032089: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d264f7b00 of size 262144 by op Add action_count 463 step 0 next 134
# 2022-04-17 23:45:24.032122: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26537b00 of size 262144 by op Fill action_count 520 step 0 next 142
# 2022-04-17 23:45:24.032153: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26577b00 of size 262144 by op Add action_count 487 step 0 next 141
# 2022-04-17 23:45:24.032181: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d265b7b00 of size 262144 by op Fill action_count 536 step 0 next 169
# 2022-04-17 23:45:24.032222: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d265f7b00 of size 131072 by op Fill action_count 538 step 0 next 171
# 2022-04-17 23:45:24.032246: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26617b00 of size 65536 by op Fill action_count 540 step 0 next 173
# 2022-04-17 23:45:24.032274: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26627b00 of size 262144 by op Fill action_count 542 step 0 next 174
# 2022-04-17 23:45:24.032305: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26667b00 of size 256 by op Fill action_count 653 step 0 next 189
# 2022-04-17 23:45:24.032342: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26667c00 of size 256 by op Fill action_count 661 step 0 next 191
# 2022-04-17 23:45:24.032374: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26667d00 of size 512 by op Fill action_count 669 step 0 next 201
# 2022-04-17 23:45:24.032405: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26667f00 of size 256 by op Fill action_count 677 step 0 next 190
# 2022-04-17 23:45:24.032438: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26668000 of size 256 by op Fill action_count 685 step 0 next 200
# 2022-04-17 23:45:24.032469: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26668100 of size 512 by op Fill action_count 693 step 0 next 206
# 2022-04-17 23:45:24.032496: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26668300 of size 256 by op Fill action_count 701 step 0 next 208
# 2022-04-17 23:45:24.032515: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26668400 of size 256 by op Fill action_count 702 step 0 next 209
# 2022-04-17 23:45:24.032534: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26668500 of size 256 by op Fill action_count 703 step 0 next 212
# 2022-04-17 23:45:24.032562: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26668600 of size 256 by op Fill action_count 710 step 0 next 210
# 2022-04-17 23:45:24.032592: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26668700 of size 256 by op Fill action_count 848 step 0 next 216
# 2022-04-17 23:45:24.032626: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26668800 of size 256 by op Fill action_count 712 step 0 next 217
# 2022-04-17 23:45:24.032658: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26668900 of size 256 by op Fill action_count 713 step 0 next 222
# 2022-04-17 23:45:24.032689: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26668a00 of size 256 by op Fill action_count 715 step 0 next 213
# 2022-04-17 23:45:24.032722: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26668b00 of size 256 by op Fill action_count 717 step 0 next 207
# 2022-04-17 23:45:24.032753: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26668c00 of size 512 by op Fill action_count 719 step 0 next 219
# 2022-04-17 23:45:24.032781: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26668e00 of size 256 by op Fill action_count 721 step 0 next 218
# 2022-04-17 23:45:24.032801: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26668f00 of size 256 by op Fill action_count 723 step 0 next 215
# 2022-04-17 23:45:24.032820: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26669000 of size 512 by op Fill action_count 725 step 0 next 199
# 2022-04-17 23:45:24.032841: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26669200 of size 256 by op Fill action_count 727 step 0 next 228
# 2022-04-17 23:45:24.032860: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26669300 of size 256 by op Fill action_count 728 step 0 next 229
# 2022-04-17 23:45:24.032879: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26669400 of size 256 by op Fill action_count 729 step 0 next 230
# 2022-04-17 23:45:24.032901: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26669500 of size 256 by op Fill action_count 731 step 0 next 232
# 2022-04-17 23:45:24.032932: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26669600 of size 256 by op Fill action_count 733 step 0 next 234
# 2022-04-17 23:45:24.032964: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26669700 of size 512 by op Fill action_count 735 step 0 next 236
# 2022-04-17 23:45:24.032997: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26669900 of size 256 by op Fill action_count 737 step 0 next 237
# 2022-04-17 23:45:24.033030: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26669a00 of size 256 by op Fill action_count 739 step 0 next 239
# 2022-04-17 23:45:24.033061: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26669b00 of size 512 by op Fill action_count 741 step 0 next 241
# 2022-04-17 23:45:24.033094: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26669d00 of size 256 by op Fill action_count 743 step 0 next 243
# 2022-04-17 23:45:24.033126: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26669e00 of size 256 by op Nadam/Cast_5/x action_count 744 step 0 next 244
# 2022-04-17 23:45:24.033155: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26669f00 of size 256 by op Nadam/add_1/y action_count 745 step 0 next 197
# 2022-04-17 23:45:24.033176: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2666a000 of size 9216 by op Add action_count 650 step 0 next 198
# 2022-04-17 23:45:24.033213: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2666c400 of size 65536 by op Fill action_count 716 step 0 next 214
# 2022-04-17 23:45:24.033247: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2667c400 of size 65536 by op Fill action_count 722 step 0 next 196
# 2022-04-17 23:45:24.033279: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2668c400 of size 65536 by op Add action_count 658 step 0 next 193
# 2022-04-17 23:45:24.033313: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2669c400 of size 65536 by op Add action_count 682 step 0 next 194
# 2022-04-17 23:45:24.033345: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266ac400 of size 20480 by op Fill action_count 726 step 0 next 227
# 2022-04-17 23:45:24.033377: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b1400 of size 9216 by op Fill action_count 730 step 0 next 231
# 2022-04-17 23:45:24.033410: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b3800 of size 256 by op Nadam/mul/x action_count 746 step 0 next 245
# 2022-04-17 23:45:24.033443: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b3900 of size 256 by op Nadam/mul_1/x action_count 747 step 0 next 246
# 2022-04-17 23:45:24.033466: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b3a00 of size 256 by op Nadam/Const action_count 748 step 0 next 247
# 2022-04-17 23:45:24.033486: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b3b00 of size 256 by op Nadam/sub_4/x action_count 749 step 0 next 248
# 2022-04-17 23:45:24.033513: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b3c00 of size 256 by op Nadam/add/y action_count 750 step 0 next 249
# 2022-04-17 23:45:24.033545: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b3d00 of size 256 by op sequential_7/batch_normalization_7/batchnorm/add/y action_count 751 step 0 next 250
# 2022-04-17 23:45:24.033580: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b3e00 of size 256 by op sequential_7/batch_normalization_7/AssignMovingAvg/decay action_count 752 step 0 next 251
# 2022-04-17 23:45:24.033612: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b3f00 of size 256 by op gradient_tape/mean_squared_error/scalar action_count 753 step 0 next 252
# 2022-04-17 23:45:24.033644: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b4000 of size 256 by op Const action_count 754 step 0 next 253
# 2022-04-17 23:45:24.033678: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b4100 of size 256 by op Nadam/Nadam/Const action_count 755 step 0 next 254
# 2022-04-17 23:45:24.033710: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b4200 of size 256 by op Fill action_count 883 step 0 next 274
# 2022-04-17 23:45:24.033742: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b4300 of size 256 by op Fill action_count 891 step 0 next 278
# 2022-04-17 23:45:24.033762: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b4400 of size 512 by op Fill action_count 899 step 0 next 291
# 2022-04-17 23:45:24.033785: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b4600 of size 256 by op Fill action_count 907 step 0 next 287
# 2022-04-17 23:45:24.033816: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b4700 of size 256 by op Fill action_count 908 step 0 next 261
# 2022-04-17 23:45:24.033846: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b4800 of size 256 by op Fill action_count 909 step 0 next 265
# 2022-04-17 23:45:24.033881: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b4900 of size 256 by op Fill action_count 916 step 0 next 267
# 2022-04-17 23:45:24.033913: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b4a00 of size 256 by op Fill action_count 1054 step 0 next 269
# 2022-04-17 23:45:24.033944: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b4b00 of size 256 by op Fill action_count 918 step 0 next 272
# 2022-04-17 23:45:24.033977: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b4c00 of size 256 by op Fill action_count 919 step 0 next 275
# 2022-04-17 23:45:24.034008: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b4d00 of size 256 by op Fill action_count 921 step 0 next 270
# 2022-04-17 23:45:24.034030: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b4e00 of size 256 by op Fill action_count 923 step 0 next 268
# 2022-04-17 23:45:24.034049: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b4f00 of size 512 by op Fill action_count 925 step 0 next 282
# 2022-04-17 23:45:24.034068: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b5100 of size 256 by op Fill action_count 927 step 0 next 281
# 2022-04-17 23:45:24.034088: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b5200 of size 256 by op Fill action_count 929 step 0 next 283
# 2022-04-17 23:45:24.034107: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b5300 of size 512 by op Fill action_count 931 step 0 next 262
# 2022-04-17 23:45:24.034131: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b5500 of size 256 by op Fill action_count 933 step 0 next 279
# 2022-04-17 23:45:24.034161: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b5600 of size 256 by op Fill action_count 934 step 0 next 263
# 2022-04-17 23:45:24.034207: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d266b5700 of size 256 by op Fill action_count 935 step 0 next 264
# ...
# 2022-04-17 23:45:24.037967: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26dea000 of size 256 by op Nadam/add/y action_count 1368 step 0 next 447
# 2022-04-17 23:45:24.037975: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26dea100 of size 256 by op sequential_10/batch_normalization_10/batchnorm/add/y action_count 1369 step 0 next 448
# 2022-04-17 23:45:24.037984: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26dea200 of size 256 by op sequential_10/batch_normalization_10/AssignMovingAvg/decay action_count 1370 step 0 next 449
# 2022-04-17 23:45:24.037996: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26dea300 of size 256 by op gradient_tape/mean_squared_error/scalar action_count 1371 step 0 next 450
# 2022-04-17 23:45:24.038009: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26dea400 of size 256 by op Const action_count 1372 step 0 next 451
# 2022-04-17 23:45:24.038021: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26dea500 of size 256 by op Nadam/Nadam/Const action_count 1373 step 0 next 452
# 2022-04-17 23:45:24.038035: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26dea600 of size 256 by op SameWorkerRecvDone action_count 1374 step 0 next 453
# 2022-04-17 23:45:24.038048: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26dea700 of size 256 by op Nadam/Nadam/update_3/mul action_count 1375 step 17536421437266244153 next 454
# 2022-04-17 23:45:24.038061: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26dea800 of size 512 by op Nadam/Nadam/update_7/mul action_count 1378 step 17536421437266244153 next 457
# 2022-04-17 23:45:24.038075: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26deaa00 of size 256 by op Nadam/Nadam/update_9/mul action_count 1380 step 17536421437266244153 next 459
# 2022-04-17 23:45:24.038088: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26deab00 of size 256 by op Nadam/Nadam/update/mul action_count 1381 step 17536421437266244153 next 460
# 2022-04-17 23:45:24.038100: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26deac00 of size 256 by op Nadam/Nadam/update_11/mul action_count 1382 step 17536421437266244153 next 461
# 2022-04-17 23:45:24.038109: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26dead00 of size 256 by op Nadam/Nadam/update_15/mul action_count 1384 step 17536421437266244153 next 463
# 2022-04-17 23:45:24.038117: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26deae00 of size 512 by op Nadam/Nadam/update_13/mul action_count 1386 step 17536421437266244153 next 465
# 2022-04-17 23:45:24.038126: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26deb000 of size 13568 by op Nadam/Nadam/update_2/mul action_count 1387 step 17536421437266244153 next 414
# 2022-04-17 23:45:24.038134: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26dee500 of size 24576 by op Add action_count 1316 step 0 next 410
# 2022-04-17 23:45:24.038142: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26df4500 of size 131072 by op Add action_count 1292 step 0 next 421
# 2022-04-17 23:45:24.038154: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26e14500 of size 262144 by op Fill action_count 1336 step 0 next 417
# 2022-04-17 23:45:24.038166: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26e54500 of size 262144 by op Add action_count 1284 step 0 next 425
# 2022-04-17 23:45:24.038178: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26e94500 of size 131072 by op Fill action_count 1338 step 0 next 395
# 2022-04-17 23:45:24.038198: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26eb4500 of size 65536 by op Fill action_count 1350 step 0 next 431
# 2022-04-17 23:45:24.038212: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26ec4500 of size 65536 by op Fill action_count 1356 step 0 next 407
# 2022-04-17 23:45:24.038226: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26ed4500 of size 262144 by op Add action_count 1308 step 0 next 405
# 2022-04-17 23:45:24.038239: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26f14500 of size 262144 by op Fill action_count 1342 step 0 next 416
# 2022-04-17 23:45:24.038252: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26f54500 of size 262144 by op Fill action_count 1352 step 0 next 433
# 2022-04-17 23:45:24.038261: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26f94500 of size 131072 by op Fill action_count 1354 step 0 next 434
# 2022-04-17 23:45:24.038269: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26fb4500 of size 262144 by op Fill action_count 1358 step 0 next 437
# 2022-04-17 23:45:24.038277: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26ff4500 of size 20480 by op Fill action_count 1360 step 0 next 439
# 2022-04-17 23:45:24.038285: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d26ff9500 of size 262144 by op Nadam/Nadam/update_6/mul action_count 1376 step 17536421437266244153 next 455
# 2022-04-17 23:45:24.038294: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27039500 of size 65536 by op Nadam/Nadam/update_4/mul action_count 1377 step 17536421437266244153 next 456
# 2022-04-17 23:45:24.038305: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27049500 of size 131072 by op Nadam/Nadam/update_8/mul action_count 1379 step 17536421437266244153 next 458
# 2022-04-17 23:45:24.038318: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27069500 of size 262144 by op Nadam/Nadam/update_12/mul action_count 1383 step 17536421437266244153 next 462
# 2022-04-17 23:45:24.038331: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d270a9500 of size 65536 by op Nadam/Nadam/update_10/mul action_count 1385 step 17536421437266244153 next 464
# 2022-04-17 23:45:24.038345: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d270b9500 of size 256 by op Nadam/Nadam/update_5/mul action_count 1388 step 17536421437266244153 next 466
# 2022-04-17 23:45:24.038359: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d270b9600 of size 256 by op Nadam/sub_2 action_count 1389 step 17536421437266244153 next 467
# 2022-04-17 23:45:24.038372: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d270b9700 of size 20480 by op Nadam/Nadam/update_14/mul action_count 1390 step 17536421437266244153 next 468
# 2022-04-17 23:45:24.038385: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d270be700 of size 256 by op Nadam/Nadam/update_15/mul_2 action_count 1391 step 17536421437266244153 next 469
# 2022-04-17 23:45:24.038399: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d270be800 of size 256 by op Nadam/Nadam/update_5/mul_2 action_count 1392 step 17536421437266244153 next 470
# 2022-04-17 23:45:24.038412: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d270be900 of size 131072 by op Nadam/Nadam/update_8/mul_2 action_count 1393 step 17536421437266244153 next 471
# 2022-04-17 23:45:24.038421: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d270de900 of size 512 by op Nadam/Nadam/update_13/mul_2 action_count 1394 step 17536421437266244153 next 472
# 2022-04-17 23:45:24.038429: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d270deb00 of size 9216 by op Nadam/Nadam/update_2/mul_2 action_count 1395 step 17536421437266244153 next 473
# 2022-04-17 23:45:24.038437: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d270e0f00 of size 262144 by op Nadam/Nadam/update_6/mul_2 action_count 1396 step 17536421437266244153 next 474
# 2022-04-17 23:45:24.038445: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27120f00 of size 256 by op Nadam/sub_3 action_count 1397 step 17536421437266244153 next 475
# 2022-04-17 23:45:24.038457: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27121000 of size 256 by op Nadam/Nadam/update_3/mul_2 action_count 1398 step 17536421437266244153 next 476
# 2022-04-17 23:45:24.038470: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27121100 of size 512 by op Nadam/Nadam/update_7/mul_2 action_count 1399 step 17536421437266244153 next 477
# 2022-04-17 23:45:24.038483: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27121300 of size 256 by op Nadam/Nadam/update_9/mul_2 action_count 1400 step 17536421437266244153 next 478
# 2022-04-17 23:45:24.038497: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27121400 of size 256 by op Nadam/Nadam/update/mul_2 action_count 1401 step 17536421437266244153 next 479
# 2022-04-17 23:45:24.038511: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27121500 of size 65536 by op Nadam/Nadam/update_10/mul_2 action_count 1402 step 17536421437266244153 next 480
# 2022-04-17 23:45:24.038524: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27131500 of size 256 by op Nadam/Nadam/update_1/mul_2 action_count 1403 step 17536421437266244153 next 481
# 2022-04-17 23:45:24.038537: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27131600 of size 256 by op Nadam/Nadam/update_11/mul_2 action_count 1404 step 17536421437266244153 next 482
# 2022-04-17 23:45:24.038551: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27131700 of size 20480 by op Nadam/Nadam/update_14/mul_2 action_count 1405 step 17536421437266244153 next 483
# 2022-04-17 23:45:24.038562: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27136700 of size 65536 by op Nadam/Nadam/update_4/mul_2 action_count 1406 step 17536421437266244153 next 484
# 2022-04-17 23:45:24.038570: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27146700 of size 262144 by op Nadam/Nadam/update_12/mul_2 action_count 1407 step 17536421437266244153 next 485
# 2022-04-17 23:45:24.038578: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27186700 of size 256 by op Nadam/Nadam/update_1/mul action_count 1408 step 17536421437266244153 next 486
# 2022-04-17 23:45:24.038587: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27186800 of size 256 by op Nadam/Cast_3 action_count 1413 step 17536421437266244153 next 487
# 2022-04-17 23:45:24.038595: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27186900 of size 256 by op Nadam/mul action_count 1415 step 17536421437266244153 next 488
# 2022-04-17 23:45:24.038608: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27186a00 of size 256 by op Nadam/Cast_4 action_count 1411 step 17536421437266244153 next 489
# 2022-04-17 23:45:24.038620: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27186b00 of size 256 by op Nadam/sub_4 action_count 1416 step 17536421437266244153 next 490
# 2022-04-17 23:45:24.038634: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27186c00 of size 256 by op Nadam/mul_7 action_count 1419 step 17536421437266244153 next 491
# 2022-04-17 23:45:24.038647: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d27186d00 of size 20480 by op SameWorkerRecvDone action_count 1420 step 0 next 492
# 2022-04-17 23:45:24.038659: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f8d2718bd00 of size 256 by op UNUSED action_count 1423 step 0 next 493
# 2022-04-17 23:45:24.038672: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f8d2718be00 of size 256 by op Cast action_count 1422 step 17536421437266244153 next 494
# 2022-04-17 23:45:24.038686: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f8d2718bf00 of size 44253440 by op UNUSED action_count 0 step 0 next 18446744073709551615
# 2022-04-17 23:45:24.038697: I tensorflow/core/common_runtime/bfc_allocator.cc:1051]      Summary of in-use Chunks by size:
# 2022-04-17 23:45:24.038714: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 293 Chunks of size 256 totalling 73.2KiB
# 2022-04-17 23:45:24.038724: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 43 Chunks of size 512 totalling 21.5KiB
# 2022-04-17 23:45:24.038733: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 768 totalling 768B
# 2022-04-17 23:45:24.038741: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 1280 totalling 1.2KiB
# 2022-04-17 23:45:24.038755: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 17 Chunks of size 9216 totalling 153.0KiB
# 2022-04-17 23:45:24.038768: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 9984 totalling 9.8KiB
# 2022-04-17 23:45:24.038782: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 10752 totalling 10.5KiB
# 2022-04-17 23:45:24.038798: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 11008 totalling 10.8KiB
# 2022-04-17 23:45:24.038811: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 13568 totalling 13.2KiB
# 2022-04-17 23:45:24.038825: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 15104 totalling 14.8KiB
# 2022-04-17 23:45:24.038841: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 16 Chunks of size 20480 totalling 320.0KiB
# 2022-04-17 23:45:24.038854: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 21504 totalling 21.0KiB
# 2022-04-17 23:45:24.038863: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 5 Chunks of size 24576 totalling 120.0KiB
# 2022-04-17 23:45:24.038872: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 31744 totalling 31.0KiB
# 2022-04-17 23:45:24.038881: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 42 Chunks of size 65536 totalling 2.62MiB
# 2022-04-17 23:45:24.038889: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 90112 totalling 88.0KiB
# 2022-04-17 23:45:24.038902: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 93440 totalling 91.2KiB
# 2022-04-17 23:45:24.038915: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 21 Chunks of size 131072 totalling 2.62MiB
# 2022-04-17 23:45:24.038930: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 164864 totalling 161.0KiB
# 2022-04-17 23:45:24.038945: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 42 Chunks of size 262144 totalling 10.50MiB
# 2022-04-17 23:45:24.038959: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 327680 totalling 320.0KiB
# 2022-04-17 23:45:24.038974: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 387584 totalling 378.5KiB
# 2022-04-17 23:45:24.038988: I tensorflow/core/common_runtime/bfc_allocator.cc:1058] Sum Total of in-use chunks: 17.55MiB
# 2022-04-17 23:45:24.038999: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] total_region_allocated_bytes_: 62652416 memory_limit_: 62652416 available bytes: 0 curr_region_allocation_bytes_: 125304832
# 2022-04-17 23:45:24.039014: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Stats:
# Limit:                        62652416
# InUse:                        18398720
# MaxInUse:                     18398976
# NumAllocs:                         958
# MaxAllocSize:                   518656
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-04-17 23:45:24.039069: W tensorflow/core/common_runtime/bfc_allocator.cc:467] ******************************______________________________________________________________________

# %%
for data in parsed_dataset.take(10):
    print(data['feature'].shape, data['label'].shape)
# Out:
# (33, 7, 7, 9) (5,)
# (33, 7, 7, 9) (5,)
# (33, 7, 7, 9) (5,)
# (33, 7, 7, 9) (5,)
# (33, 7, 7, 9) (5,)
# (33, 7, 7, 9) (5,)
# (33, 7, 7, 9) (5,)
# (33, 7, 7, 9) (5,)
# (33, 7, 7, 9) (5,)
# (33, 7, 7, 9) (5,)

# %% [markdown]
# # testtest

# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler


def pad_boundary(arr, kernel_size):
    '''
    arr : input array
    kernel_size : training sample size
    '''

    pad_size = int((kernel_size - 1) / 2)

    if len(arr.shape) == 5:
        pad_arr = np.pad(arr, pad_size, 'wrap')
        pad_arr = pad_arr[pad_size:-pad_size, pad_size:-pad_size, ..., pad_size:-pad_size]
    else:
        raise ValueError('len(arr.shape) should be 5')
    return pad_arr


def sliding_window_x(arr, z=33, y=7, x=7, f=9, kernel_size=7):
    arr = np.lib.stride_tricks.sliding_window_view(arr,
                                                   (kernel_size, kernel_size),
                                                   axis=(2, 3))
    arr = np.moveaxis(arr, 4, -1)
    arr = np.moveaxis(arr, 1, 3)
    arr = arr.reshape(-1, z, y, x, f)
    return arr


def load_X(dir_path, feature_range=(0, 1)):
    Vars = []
    names = [p.name for p in Path(dir_path).glob('*/')]
    for name in names:
        path = Path(dir_path).joinpath(name)
        data = np.stack([np.load(p) for p in path.glob('*.npy')])
        if name == 'cape':
            data = data[:, np.newaxis, ..., np.newaxis]
            data = np.concatenate([data]*34, axis=1)
        else:
            data = data[..., np.newaxis]
        Vars.append(data)
    X = np.concatenate(Vars, axis=-1)[:, 1:, ...]
    X = np.moveaxis(X, 1, -2)
    shape = X.shape
        
    # stdandardlization
    scaler = MinMaxScaler(feature_range=feature_range)
    X = X.reshape(-1, 9)
    X = scaler.fit_transform(X)
    X = X.reshape(shape)
    
    return X.astype(np.float32), scaler


def X_ETL(path, idx, nb_test_samples, mode='train', feature_range=(0,1), pickle_save_dir='models_save/test1/pickles'):
    # load_X and select train/val/test set due to lack of memory
    X, scaler = load_X(path, feature_range)
    nb_test_samples = int(0.2 * X.shape[0])
    
    # shuffle
    X = X[idx]
    
    # split
    if mode is 'train':
        X = X[2*nb_test_samples:]
    elif mode is 'val':
        X = X[0:nb_test_samples]
    else:
        X = X[nb_test_samples:2*nb_test_samples]
    
    print(X.shape)
    # CNN input style
    X = pad_boundary(X, 7)
    print(X.shape)
    X = np.lib.stride_tricks.sliding_window_view(X, (7, 7), axis=(1, 2))
    print(X.shape)
    X = np.moveaxis(X, 4, -1)
    print(X.shape)
    
    # save scaler and pca as pickles
    if mode is 'train':
        Path(pickle_save_dir).mkdir(parents=True, exist_ok=True)
        pickle.dump(scaler, open(f'{pickle_save_dir}/scaler_X.pkl', 'wb'))
    return X.reshape(-1, 33, 7, 7, 9)


def y_ETL(dir_path, idx, nb_test_samples, mode='train', feature_range=(0, 1), pickle_save_dir='models_save/test1/pickles'):
    # load from folder
    whs = list(Path(dir_path).glob('*.npy'))
    whs = np.stack([np.load(path) for path in whs])
    print(whs.shape)
    nb_test_samples = int(0.2 * whs.shape[0])
    whs = whs[idx]
    if mode is 'train':
        whs = whs[2*nb_test_samples:]
    elif mode is 'val':
        whs = whs[0:nb_test_samples]
    else:
        whs = whs[nb_test_samples:2*nb_test_samples]    
    
    # move sample axis to the last, reshape, and remove the first layer
    whs = np.moveaxis(whs, 1, 3).reshape(-1, 34)[:, 1:]
    
    # Min Max normalization
    scaler = MinMaxScaler(feature_range=feature_range)
    scaled_whs = scaler.fit_transform(whs)
    
    # PCA
    pca = PCA(n_components=0.96, svd_solver='full')
    out = pca.fit_transform(scaled_whs)
    
    # save scaler and pca as pickles
    if mode is 'train':
        Path(pickle_save_dir).mkdir(parents=True, exist_ok=True)
        pickle.dump(scaler, open(f'{pickle_save_dir}/scaler.pkl', 'wb'))
        pickle.dump(pca, open(f'{pickle_save_dir}/pca.pkl', 'wb'))
    return out.astype(np.float32), pca

# save tf_record data
def parse_single_data(feature, label):
    #define the dictionary -- the structure -- of our single example
    data = {
        'feature' : _bytes_feature(tf.io.serialize_tensor(feature).numpy()),
        'label' : _bytes_feature(tf.io.serialize_tensor(label).numpy())
    }

    out = tf.train.Example(features=tf.train.Features(feature=data))
    return out

def write_data_to_tfr_short(datas, labels, filename:str="data"):
    filename= filename+".tfrecords"
    writer = tf.io.TFRecordWriter(filename) #create a writer that'll store our data to disk
    count = 0

    for index in range(len(datas)):

        #get the data we want to write
        current_data = datas[index]
        current_label = labels[index]

        out = parse_single_data(feature=current_data, label=current_label)
        writer.write(out.SerializeToString())
        count += 1

    writer.close()
    print(f"Wrote {count} elements to TFRecord")
    return count


# parse tf_record data
def _parse_data_function(example_proto):
    data_feature_description = {
        'feature' : tf.io.FixedLenFeature([], tf.string),
        'label' : tf.io.FixedLenFeature([], tf.string)
    }

    # Parse the input tf.train.Example proto using the dictionary above.
    features = tf.io.parse_single_example(example_proto, data_feature_description)
    data = tf.io.parse_tensor(features['feature'], "float") 
    label = tf.io.parse_tensor(features['label'], "float")
    data.set_shape([33,7,7,9])
    label.set_shape([5,])
    return data, label


def get_dataset(dataset, BATCH_SIZE):
    dataset = dataset.shuffle(2048)
    dataset = dataset.prefetch(buffer_size=AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE)

    return dataset

# %%
import random

# Settings
mode = 'test'
save_name_suffix = '0421'
X_path = 'data/vars/'
y_path = 'data/target/wh/'
pickle_save_dir='model_save/test2/pickles'

# set seed for reproduce
seed = 777
idx = np.arange(1314)
random.seed(seed)
random.shuffle(idx)
nb_test_samples = int(0.2 * idx.shape[0])

# X pre-process
X = X_ETL(X_path, idx, nb_test_samples, mode=mode, pickle_save_dir=pickle_save_dir)
# Out:
# (262, 32, 32, 33, 9)
# (262, 32, 38, 39, 9)
# (262, 26, 32, 39, 9, 7, 7)
# (262, 26, 32, 39, 7, 7, 9)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3390085/1584861039.py in <module>
#      16
#      17 # X pre-process
# ---> 18 X = X_ETL(X_path, idx, nb_test_samples, mode=mode, pickle_save_dir=pickle_save_dir)
#
# /tmp/ipykernel_3390085/2323926692.py in X_ETL(path, idx, nb_test_samples, mode, feature_range, pickle_save_dir)
#      88         Path(pickle_save_dir).mkdir(parents=True, exist_ok=True)
#      89         pickle.dump(scaler, open(f'{pickle_save_dir}/scaler_X.pkl', 'wb'))
# ---> 90     return X.reshape(-1, 33, 7, 7, 9)
#      91
#      92
#
# ValueError: cannot reshape array of size 3749106816 into shape (33,7,7,9)
